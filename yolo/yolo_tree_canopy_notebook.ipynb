# %% [markdown]
# # YOLO Detection Toolbox for Jupyter Notebook
#
# Click a button to run **Train**, or **Predict** mode.
# All settings are automatically loaded from `dataset_path.yaml`.

# %% [markdown]
# ## Train YOLO

# %%
# Train
# %run yolo_tree_canopy_model_train.py --yaml-file yolo_dataset.yaml

# %%
# Train with autolog - Please check `yolo\train_logs` folder for logs. 
import sys
# !{sys.executable} -u yolo_tree_canopy_model_train_autolog.py --yaml-file yolo_dataset.yaml

# %% [markdown]
# ## Predict YOLO

# %%
# Predict
# %run yolo_tree_canopy_model_predict.py \
    --model "yolo_model.pt" \
    --source "../BH_CT_Data/yolo_dataset/test/images"
# Out:
# PyTorch Version: 2.1.0+cu121
# CUDA Available: True
# CUDA Device Count: 1
# Device 0: NVIDIA GeForce RTX 2070 Super with Max-Q Design
# ...
# Prediction started with model=e:/_USC/git/urban-tree-canopy/yolo/yolo_model.pt
#   source    : e:/_USC/git/urban-tree-canopy/BH_CT_Data/yolo_dataset/test/images
#   imgsz     : 320
#   conf      : 0.5
#   iou       : 0.5
#   device    : 0
#   save_txt  : False
#   save_conf : False
#   save_crop : False
#   name      : predict_imgsz320_conf0.5_iou0.5_4
# ...
# Prediction completed for predict_imgsz320_conf0.5_iou0.5_4.
#   Script Logs saved to : e:/_USC/git/urban-tree-canopy/yolo/predict_logs/predict_imgsz320_conf0.5_iou0.5_4/predict_imgsz320_conf0.5_iou0.5_4.log
#   YOLO Results saved to: e:/_USC/git/urban-tree-canopy/yolo/runs/detect/predict_imgsz320_conf0.5_iou0.5_4
# ------------------------------------------------------------------------
# Execution time: 0h 0m 11.58s
# ...

# %% [markdown]
# ---
# To change settings, edit `yolo/dataset_path.yaml` and **re-run this notebook**.
# All paths and hyperparameters are automatically loaded from the YAML file.
