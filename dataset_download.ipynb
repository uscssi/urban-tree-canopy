# %% [markdown]
# # Download Sample Datasets and Models

# %%
# %run dataset_download.py
# Out:
# ...
#   100.0% (608.1 MB / 608.1 MB)
#   Download complete.
# Extracting BH_CT_Data.zip -> ./BH_CT_Data ...
#   Extraction complete.
# Dataset ready: BH_CT_Data/
#
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1hWFd7PUgJ7G9tBFsMSlj6LmD_1AF1ivt
# From (redirected): https://drive.google.com/uc?id=1hWFd7PUgJ7G9tBFsMSlj6LmD_1AF1ivt&confirm=t&uuid=cf80a983-e061-43a7-be73-7040b90f6831
# To: e:\_USC\git\urban-tree-canopy\unet_model_ex.zip
# 100%|██████████| 182M/182M [00:02<00:00, 64.2MB/s]
#   Download complete.
# Extracting unet_model_ex.zip -> unet ...
#   Extraction complete.
#   Removed unet_model_ex.zip
# Unet Sample Model ready: unet/train/, unet/test/, unet/predict/
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=175g8OV_Uc-I7-ecg3F0X5nL2r0meqLY0
# From (redirected): https://drive.google.com/uc?id=175g8OV_Uc-I7-ecg3F0X5nL2r0meqLY0&confirm=t&uuid=fcdc3ee3-7e45-4de6-8125-a897df1bef8b
# To: e:\_USC\git\urban-tree-canopy\yolo\yolo_model.pt
# ...

# %%
# If you need to download pre-trained models only:
# %run dataset_download.py --models

# %%
# If you need to download the dataset only:
# %run dataset_download.py --dataset
